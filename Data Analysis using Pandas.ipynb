# %%
import pandas as pd

# %%
application_record_df = pd.read_csv("application_record.csv")

# %%
type(application_record_df)
# Out:
# pandas.core.frame.DataFrame

# %%
application_record_df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment      -12005          -4542
# 1        Civil marriage   Rented apartment      -12005          -4542
# 2               Married  House / apartment      -21474          -1134
# 3  Single / not married  House / apartment      -19110          -3051
# 4  Single / not married  House / apartment      -19110          -3051
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0             NaN
# 1           1                1           0           0             NaN
# 2           1                0           0           0  Security staff
# 3           1                0           1           1     Sales staff
# 4           1                0           1           1     Sales staff
#
#    CNT_FAM_MEMBERS
# 0                2
# 1                2
# 2                2
# 3                1
# 4                1

# %%
application_record_df.tail()
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 438552                1
# 438553                1
# 438554                1
# 438555                2
# 438556                2

# %% [markdown]
# ### Read Excel file in Pandas

# %%
app_rec_excel_df = pd.read_excel("D:\LDS\DataAnalysisWithPython\Credit_Analysis_Spreadsheet.xls")

# %%
app_rec_excel_df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment      -12005          -4542
# 1        Civil marriage   Rented apartment      -12005          -4542
# 2               Married  House / apartment      -21474          -1134
# 3  Single / not married  House / apartment      -19110          -3051
# 4  Single / not married  House / apartment      -19110          -3051
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0             NaN
# 1           1                1           0           0             NaN
# 2           1                0           0           0  Security staff
# 3           1                0           1           1     Sales staff
# 4           1                0           1           1     Sales staff
#
#    CNT_FAM_MEMBERS
# 0                2
# 1                2
# 2                2
# 3                1
# 4                1

# %%
app_rec_excel_df.tail()
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 65530  5235790           F            N               Y             0
# 65531  5235791           F            N               Y             0
# 65532  5235792           F            N               Y             0
# 65533  5235793           F            N               Y             0
# 65534  5235794           F            N               Y             0
#
#        AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 65530          135000.0        Pensioner  Secondary / secondary special
# 65531          135000.0        Pensioner  Secondary / secondary special
# 65532          135000.0        Pensioner  Secondary / secondary special
# 65533          135000.0        Pensioner  Secondary / secondary special
# 65534          135000.0        Pensioner  Secondary / secondary special
#
#       NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 65530            Married  House / apartment      -20553         365243
# 65531            Married  House / apartment      -20553         365243
# 65532            Married  House / apartment      -20553         365243
# 65533            Married  House / apartment      -20553         365243
# 65534            Married  House / apartment      -20553         365243
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 65530           1                0           0           0             NaN
# 65531           1                0           0           0             NaN
# 65532           1                0           0           0             NaN
# 65533           1                0           0           0             NaN
# 65534           1                0           0           0             NaN
#
#        CNT_FAM_MEMBERS
# 65530                2
# 65531                2
# 65532                2
# 65533                2
# 65534                2

# %%
credit_info_df = pd.read_excel("D:\LDS\DataAnalysisWithPython\Credit_Analysis_Spreadsheet.xls", sheet_name = "credit_record")

# %%
credit_info_df.head(10)
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C
# 5  5001712              -1      C
# 6  5001712              -2      C
# 7  5001712              -3      C
# 8  5001712              -4      C
# 9  5001712              -5      C

# %%
app_rec_excel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   65535 non-null  int64
#  1   CODE_GENDER          65535 non-null  object
#  2   FLAG_OWN_CAR         65535 non-null  object
#  3   FLAG_OWN_REALTY      65535 non-null  object
#  4   CNT_CHILDREN         65535 non-null  int64
#  5   AMT_INCOME_TOTAL     65535 non-null  float64
#  6   NAME_INCOME_TYPE     65535 non-null  object
#  7   NAME_EDUCATION_TYPE  65535 non-null  object
#  8   NAME_FAMILY_STATUS   65535 non-null  object
#  9   NAME_HOUSING_TYPE    65535 non-null  object
#  10  DAYS_BIRTH           65535 non-null  int64
#  11  DAYS_EMPLOYED        65535 non-null  int64
#  12  FLAG_MOBIL           65535 non-null  int64
#  13  FLAG_WORK_PHONE      65535 non-null  int64
#  14  FLAG_PHONE           65535 non-null  int64
#  15  FLAG_EMAIL           65535 non-null  int64
#  16  OCCUPATION_TYPE      44855 non-null  object
#  17  CNT_FAM_MEMBERS      65535 non-null  int64
# dtypes: float64(1), int64(9), object(8)
# memory usage: 9.0+ MB

# %%
credit_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              65535 non-null  int64
#  1   MONTHS_BALANCE  65535 non-null  int64
#  2   STATUS          65535 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 1.5+ MB

# %%
app_rec_excel_df.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'],
#       dtype='object')

# %%
credit_info_df.shape
# Out:
# (65535, 3)

# %%
credit_info_df.index
# Out:
# RangeIndex(start=0, stop=65535, step=1)

# %%
credit_info_df.columns
# Out:
# Index(['ID', 'MONTHS_BALANCE', 'STATUS'], dtype='object')
